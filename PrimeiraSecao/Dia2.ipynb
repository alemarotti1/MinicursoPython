# %% [markdown]
# # Matplotlib
# Criação de gráficos
#
# # Seaborn
#
#
# # Pandas
# O que é
#
# Basicamente uma planilha do excel ou uma tabela do banco de dados só que armazenada em uma variável
#
#
# # Numpy
